# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

x_train = [1, 2, 3]
y_train = [1, 2, 3]

# 텐서플로에서 변동하는 값을 의미
W = tf.Variable(tf.random_normal([1]), name="weight")
b = tf.Variable(tf.random_normal([1]), name="bias")

# W, b 를 바탕으로 cost 값이 최소가 되는 W, b를 구함
hypothesis = x_train * W + b

# reduce_mean==평균 / square== 제곱
cost = tf.reduce_mean(tf.square(hypothesis - y_train))

# W,b의 최소값을 구함
train = tf.train.GradientDescentOptimizer(learning_rate=0.01).minimize(cost)

with tf.Session() as sess:    
    sess.run(tf.global_variables_initializer())

    for step in range(2001):
        _, cost_val, W_val, b_val = sess.run([train, cost, W, b])
        if step % 20 == 0:
            print(step, cost_val, W_val, b_val)
# Out:
# 0 11.055341 [0.14207931] [-1.1582853]
# 20 0.1557188 [1.1651936] [-0.6715169]
# 40 0.051802497 [1.2510111] [-0.59879154]
# 60 0.04623526 [1.2481254] [-0.5667308]
# 80 0.041984275 [1.2373129] [-0.5397234]
# 100 0.038130727 [1.2262408] [-0.5143229]
# 120 0.03463093 [1.215616] [-0.49014825]
# 140 0.031452354 [1.2054834] [-0.4671127]
# 160 0.028565511 [1.1958266] [-0.44516]
# 180 0.025943674 [1.1866236] [-0.42423916]
# 200 0.023562469 [1.1778529] [-0.4043015]
# 220 0.021399813 [1.1694945] [-0.38530082]
# 240 0.019435631 [1.1615286] [-0.36719298]
# 260 0.017651754 [1.1539375] [-0.3499362]
# 280 0.016031586 [1.146703] [-0.33349046]
# 300 0.014560166 [1.1398085] [-0.3178177]
# 320 0.01322376 [1.1332381] [-0.30288142]
# 340 0.012010043 [1.1269763] [-0.28864712]
# 360 0.010907698 [1.1210086] [-0.27508172]
# 380 0.009906552 [1.1153219] [-0.2621538]
# 400 0.008997283 [1.1099021] [-0.24983352]
# 420 0.008171481 [1.1047373] [-0.23809221]
# 440 0.0074214637 [1.0998149] [-0.22690278]
# 460 0.0067402977 [1.095124] [-0.21623915]
# 480 0.0061216466 [1.0906535] [-0.20607674]
# 500 0.005559771 [1.0863931] [-0.19639188]
# 520 0.0050494843 [1.0823332] [-0.18716222]
# 540 0.0045860154 [1.0784636] [-0.17836632]
# 560 0.004165088 [1.074776] [-0.16998373]
# 580 0.003782807 [1.0712619] [-0.16199508]
# 600 0.0034356024 [1.0679129] [-0.15438192]
# 620 0.0031202715 [1.0647212] [-0.14712653]
# 640 0.002833885 [1.0616796] [-0.14021221]
# 660 0.0025737765 [1.0587808] [-0.1336227]
# 680 0.0023375412 [1.0560184] [-0.1273429]
# 700 0.0021229906 [1.0533857] [-0.12135827]
# 720 0.0019281363 [1.0508769] [-0.11565491]
# 740 0.0017511646 [1.0484858] [-0.11021953]
# 760 0.0015904332 [1.0462071] [-0.10503963]
# 780 0.0014444563 [1.0440356] [-0.10010312]
# 800 0.0013118829 [1.0419662] [-0.09539868]
# 820 0.0011914779 [1.039994] [-0.09091549]
# 840 0.0010821173 [1.0381143] [-0.08664276]
# 860 0.0009827963 [1.036323] [-0.08257081]
# 880 0.0008925901 [1.034616] [-0.07869026]
# 900 0.0008106653 [1.0329891] [-0.07499216]
# 920 0.00073625724 [1.0314388] [-0.0714678]
# 940 0.0006686814 [1.0299612] [-0.06810912]
# 960 0.000607307 [1.0285532] [-0.06490824]
# 980 0.0005515683 [1.0272114] [-0.0618578]
# 1000 0.00050094293 [1.0259326] [-0.05895072]
# 1020 0.00045496473 [1.0247138] [-0.05618028]
# 1040 0.00041320684 [1.0235524] [-0.05354003]
# 1060 0.00037528077 [1.0224454] [-0.05102385]
# 1080 0.00034083604 [1.0213908] [-0.04862597]
# 1100 0.00030955972 [1.0203859] [-0.04634098]
# 1120 0.00028114687 [1.0194273] [-0.04416328]
# 1140 0.00025534007 [1.0185144] [-0.04208766]
# 1160 0.00023190225 [1.0176442] [-0.04010965]
# 1180 0.00021061738 [1.016815] [-0.03822456]
# 1200 0.00019128679 [1.0160247] [-0.03642812]
# 1220 0.00017372966 [1.0152718] [-0.03471614]
# 1240 0.00015778399 [1.014554] [-0.03308464]
# 1260 0.00014330132 [1.0138701] [-0.03152978]
# 1280 0.00013015016 [1.0132182] [-0.03004805]
# 1300 0.00011820378 [1.012597] [-0.02863588]
# 1320 0.00010735465 [1.012005] [-0.02729011]
# 1340 9.750146e-05 [1.0114409] [-0.0260076]
# 1360 8.855215e-05 [1.0109031] [-0.02478534]
# 1380 8.042492e-05 [1.0103906] [-0.0236205]
# 1400 7.3042225e-05 [1.0099022] [-0.02251039]
# 1420 6.633836e-05 [1.0094368] [-0.02145241]
# 1440 6.0249014e-05 [1.0089934] [-0.0204442]
# 1460 5.4719214e-05 [1.0085708] [-0.01948342]
# 1480 4.9696395e-05 [1.008168] [-0.01856777]
# 1500 4.5134846e-05 [1.0077841] [-0.01769511]
# 1520 4.0992953e-05 [1.0074184] [-0.01686354]
# 1540 3.723052e-05 [1.0070697] [-0.01607105]
# 1560 3.3813267e-05 [1.0067375] [-0.01531576]
# 1580 3.070917e-05 [1.0064207] [-0.01459593]
# 1600 2.7890952e-05 [1.006119] [-0.01390998]
# 1620 2.5331035e-05 [1.0058315] [-0.01325626]
# 1640 2.300571e-05 [1.0055574] [-0.01263328]
# 1660 2.0894156e-05 [1.0052962] [-0.01203956]
# 1680 1.897667e-05 [1.0050473] [-0.01147374]
# 1700 1.7234457e-05 [1.0048101] [-0.01093447]
# 1720 1.5652766e-05 [1.004584] [-0.01042056]
# 1740 1.42158815e-05 [1.0043687] [-0.00993082]
# 1760 1.2911748e-05 [1.0041634] [-0.00946417]
# 1780 1.1726145e-05 [1.0039676] [-0.00901939]
# 1800 1.0649859e-05 [1.0037812] [-0.00859552]
# 1820 9.672789e-06 [1.0036035] [-0.00819155]
# 1840 8.7850385e-06 [1.0034342] [-0.0078066]
# 1860 7.978603e-06 [1.0032728] [-0.00743975]
# 1880 7.2461953e-06 [1.003119] [-0.00709014]
# 1900 6.5811514e-06 [1.0029725] [-0.00675694]
# 1920 5.977239e-06 [1.0028328] [-0.00643939]
# 1940 5.428898e-06 [1.0026996] [-0.00613682]
# 1960 4.9304617e-06 [1.0025729] [-0.00584846]
# 1980 4.478164e-06 [1.0024518] [-0.00557364]
# 2000 4.06723e-06 [1.0023367] [-0.00531172]
